# %%
import os
import scipy.io
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

img_dir = "/home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img"
mat_dir = "/home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/mats"
model = YOLO("/home/stevenyang/Desktop/cmput469/YOLO/runs/detect/crowd_counting_v11/weights/best.pt")

# %%
import os
import cv2
import scipy.io
import matplotlib.pyplot as plt
import torch

def plot_ground_truth_and_prediction(index):
    img_file = f"{index:04d}.jpg" 
    img_path = os.path.join(img_dir, img_file)
    mat_file = f"{index:04d}.mat"
    mat_path = os.path.join(mat_dir, mat_file)

    if not os.path.exists(img_path):
        print(f"Image file {img_path} not found.")
        return

    if not os.path.exists(mat_path):
        print(f"Annotation file {mat_path} not found.")
        return

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    mat_data = scipy.io.loadmat(mat_path)
    ann_boxes = mat_data['annBoxes']
    ground_truth_count = len(ann_boxes)

    results = model.predict(source=img_path, conf=0.5)
    predicted_count = sum(len(result.boxes) for result in results)

    plt.figure(figsize=(10, 10))
    plt.imshow(img)

    for box in ann_boxes:
        x_min, y_min, x_max, y_max = box
        plt.gca().add_patch(plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min, edgecolor='red', linewidth=2, fill=False))


    # Plot predicted bounding boxes
    for result in results:
        for box in result.boxes.xyxy.cpu().numpy():
            x_min, y_min, x_max, y_max = box[:4]
            plt.gca().add_patch(
                plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                              edgecolor='blue', linewidth=2, fill=False)
            )

    plt.title(f"Predicted: {predicted_count}, Ground Truth: {ground_truth_count}")
    plt.legend()
    plt.axis("off")
    plt.show()

# %%
import os
import cv2
import scipy.io
import matplotlib.pyplot as plt
import torch

def plot_ground_truth_and_prediction(index):
    img_file = f"{index:04d}.jpg" 
    img_path = os.path.join(img_dir, img_file)
    mat_file = f"{index:04d}.mat"
    mat_path = os.path.join(mat_dir, mat_file)

    if not os.path.exists(img_path):
        print(f"Image file {img_path} not found.")
        return

    if not os.path.exists(mat_path):
        print(f"Annotation file {mat_path} not found.")
        return

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    mat_data = scipy.io.loadmat(mat_path)
    GT_loc = mat_data['annPoints']
    ground_truth_count = len(GT_loc)

    results = model.predict(source=img_path, conf=0.5)
    predicted_count = sum(len(result.boxes) for result in results)

    plt.figure(figsize=(10, 10))
    plt.imshow(img)

    # Plot ground truth locations as red dots
    plt.scatter(GT_loc[:, 0], GT_loc[:, 1], c='red', s=10, label="Ground Truth")

    # Plot predicted bounding boxes
    for result in results:
        for box in result.boxes.xyxy.cpu().numpy():
            x_min, y_min, x_max, y_max = box[:4]
            plt.gca().add_patch(
                plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                              edgecolor='blue', linewidth=2, fill=False)
            )

    plt.title(f"Predicted: {predicted_count}, Ground Truth: {ground_truth_count}")
    plt.legend()
    plt.axis("off")
    plt.show()

# %%
plot_ground_truth_and_prediction(291)
# Out:
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0291.jpg: 864x1280 36 pps, 65.3ms
# Speed: 20.6ms preprocess, 65.3ms inference, 1.6ms postprocess per image at shape (1, 3, 864, 1280)

# %%
import os
import cv2
import scipy.io
import matplotlib.pyplot as plt
from ultralytics import YOLO

img_dir = "/home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img"
mat_dir = "/home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/mats"
model = YOLO("/home/stevenyang/Desktop/cmput469/YOLO/runs/detect/crowd_counting_v11/weights/best.pt")

def eval(index):
    img_file = f"{index:04d}.jpg" 
    img_path = os.path.join(img_dir, img_file)
    mat_file = f"{index:04d}.mat"
    mat_path = os.path.join(mat_dir, mat_file)

    if not os.path.exists(img_path):
        print(f"Image file {img_path} not found.")
        return None, None

    if not os.path.exists(mat_path):
        print(f"Annotation file {mat_path} not found.")
        return None, None

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    mat_data = scipy.io.loadmat(mat_path)
    GT_loc = mat_data['annBoxes']
    ground_truth_count = len(GT_loc)

    # if ground_truth_count > 20:
    #     return None, None

    results = model.predict(source=img_path, conf=0.5)
    predicted_count = sum(len(result.boxes) for result in results)

    return ground_truth_count, predicted_count

mae = 0
mape = 0
count = 0

for x in range(1,685):
    gt, p = eval(x)
    if gt is not None and p is not None:
        err = abs(int(gt) - int(p))
        mae += err
        mape += err / gt
        count += 1


mae = mae / count
mape = (mape / count) * 100


print(f"MAE: {mae}")
print(f"MAPE: {mape}%")
# Out:
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0001.jpg: 896x1280 7 pps, 49.8ms
# Speed: 4.8ms preprocess, 49.8ms inference, 0.9ms postprocess per image at shape (1, 3, 896, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0002.jpg: 960x1280 28 pps, 53.9ms
# Speed: 5.4ms preprocess, 53.9ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0003.jpg: 960x1280 31 pps, 53.0ms
# Speed: 4.9ms preprocess, 53.0ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0004.jpg: 864x1280 28 pps, 48.8ms
# Speed: 5.0ms preprocess, 48.8ms inference, 0.8ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0005.jpg: 864x1280 23 pps, 46.4ms
# Speed: 4.6ms preprocess, 46.4ms inference, 1.3ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0006.jpg: 960x1280 23 pps, 53.1ms
# Speed: 5.3ms preprocess, 53.1ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0007.jpg: 800x1280 43 pps, 42.0ms
# Speed: 3.7ms preprocess, 42.0ms inference, 1.1ms postprocess per image at shape (1, 3, 800, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0008.jpg: 864x1280 6 pps, 45.3ms
# Speed: 4.5ms preprocess, 45.3ms inference, 0.8ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0009.jpg: 736x1280 8 pps, 36.1ms
# Speed: 4.4ms preprocess, 36.1ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0010.jpg: 960x1280 12 pps, 49.0ms
# Speed: 5.6ms preprocess, 49.0ms inference, 1.2ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0011.jpg: 960x1280 31 pps, 50.4ms
# Speed: 5.5ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0012.jpg: 960x1280 13 pps, 49.9ms
# Speed: 4.9ms preprocess, 49.9ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0013.jpg: 736x1280 22 pps, 38.1ms
# Speed: 4.3ms preprocess, 38.1ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0014.jpg: 928x1280 15 pps, 50.0ms
# Speed: 4.4ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 928, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0015.jpg: 896x1280 20 pps, 44.4ms
# Speed: 5.0ms preprocess, 44.4ms inference, 1.0ms postprocess per image at shape (1, 3, 896, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0016.jpg: 960x1280 13 pps, 52.4ms
# Speed: 4.8ms preprocess, 52.4ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0017.jpg: 544x1280 8 pps, 30.3ms
# Speed: 3.3ms preprocess, 30.3ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0018.jpg: 960x1280 28 pps, 48.7ms
# Speed: 5.5ms preprocess, 48.7ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0019.jpg: 864x1280 12 pps, 43.7ms
# Speed: 5.1ms preprocess, 43.7ms inference, 1.2ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0020.jpg: 864x1280 17 pps, 43.7ms
# Speed: 5.3ms preprocess, 43.7ms inference, 1.7ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0021.jpg: 800x1280 21 pps, 39.5ms
# Speed: 4.7ms preprocess, 39.5ms inference, 3.0ms postprocess per image at shape (1, 3, 800, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0022.jpg: 960x1280 22 pps, 50.2ms
# Speed: 7.6ms preprocess, 50.2ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0023.jpg: 864x1280 12 pps, 44.3ms
# Speed: 4.9ms preprocess, 44.3ms inference, 1.1ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0024.jpg: 736x1280 31 pps, 37.2ms
# Speed: 4.3ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0025.jpg: 960x1280 26 pps, 51.8ms
# Speed: 5.8ms preprocess, 51.8ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0026.jpg: 960x1280 36 pps, 52.0ms
# Speed: 5.6ms preprocess, 52.0ms inference, 1.4ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0027.jpg: 864x1280 8 pps, 43.5ms
# Speed: 5.2ms preprocess, 43.5ms inference, 3.0ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0028.jpg: 736x1280 30 pps, 39.1ms
# Speed: 4.0ms preprocess, 39.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0029.jpg: 736x1280 25 pps, 39.5ms
# Speed: 3.8ms preprocess, 39.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0030.jpg: 960x1280 29 pps, 48.4ms
# Speed: 5.7ms preprocess, 48.4ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0031.jpg: 960x1280 35 pps, 48.9ms
# Speed: 5.3ms preprocess, 48.9ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0032.jpg: 960x1280 5 pps, 49.2ms
# Speed: 5.3ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0033.jpg: 864x1280 15 pps, 42.1ms
# Speed: 5.2ms preprocess, 42.1ms inference, 2.4ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0034.jpg: 960x1280 24 pps, 49.5ms
# Speed: 5.5ms preprocess, 49.5ms inference, 1.2ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0035.jpg: 864x1280 18 pps, 42.9ms
# Speed: 5.4ms preprocess, 42.9ms inference, 1.0ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0036.jpg: 864x1280 8 pps, 42.2ms
# Speed: 4.9ms preprocess, 42.2ms inference, 1.3ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0037.jpg: 864x1280 25 pps, 43.6ms
# Speed: 4.8ms preprocess, 43.6ms inference, 1.1ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0038.jpg: 960x1280 28 pps, 48.9ms
# Speed: 5.2ms preprocess, 48.9ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0039.jpg: 1280x864 20 pps, 52.0ms
# Speed: 5.1ms preprocess, 52.0ms inference, 1.1ms postprocess per image at shape (1, 3, 1280, 864)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0040.jpg: 960x1280 36 pps, 57.7ms
# Speed: 5.3ms preprocess, 57.7ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0041.jpg: 640x1280 38 pps, 33.1ms
# Speed: 4.7ms preprocess, 33.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0042.jpg: 928x1280 18 pps, 49.0ms
# Speed: 5.1ms preprocess, 49.0ms inference, 0.8ms postprocess per image at shape (1, 3, 928, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0043.jpg: 864x1280 14 pps, 45.9ms
# Speed: 4.9ms preprocess, 45.9ms inference, 0.9ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0044.jpg: 864x1280 26 pps, 46.8ms
# Speed: 5.2ms preprocess, 46.8ms inference, 1.4ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0045.jpg: 864x1280 51 pps, 46.2ms
# Speed: 5.0ms preprocess, 46.2ms inference, 1.1ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0046.jpg: 736x1280 30 pps, 39.2ms
# Speed: 4.3ms preprocess, 39.2ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0047.jpg: 960x1280 25 pps, 51.4ms
# Speed: 5.5ms preprocess, 51.4ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0048.jpg: 960x1280 16 pps, 51.1ms
# Speed: 5.3ms preprocess, 51.1ms inference, 1.6ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0049.jpg: 960x1280 33 pps, 51.1ms
# Speed: 5.4ms preprocess, 51.1ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0050.jpg: 960x1280 8 pps, 50.1ms
# Speed: 5.6ms preprocess, 50.1ms inference, 1.5ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0051.jpg: 960x1280 9 pps, 52.0ms
# Speed: 5.3ms preprocess, 52.0ms inference, 1.1ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0052.jpg: 1280x960 17 pps, 53.0ms
# Speed: 5.8ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 1280, 960)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0053.jpg: 960x1280 14 pps, 52.0ms
# Speed: 5.5ms preprocess, 52.0ms inference, 1.2ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0054.jpg: 864x1280 21 pps, 47.1ms
# Speed: 5.4ms preprocess, 47.1ms inference, 0.9ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0055.jpg: 864x1280 37 pps, 45.9ms
# Speed: 5.4ms preprocess, 45.9ms inference, 1.4ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0056.jpg: 864x1280 27 pps, 59.3ms
# Speed: 4.1ms preprocess, 59.3ms inference, 2.0ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0057.jpg: 960x1280 58 pps, 65.3ms
# Speed: 5.1ms preprocess, 65.3ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0058.jpg: 1280x1280 5 pps, 70.4ms
# Speed: 6.7ms preprocess, 70.4ms inference, 0.8ms postprocess per image at shape (1, 3, 1280, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0059.jpg: 800x1280 36 pps, 40.4ms
# Speed: 5.0ms preprocess, 40.4ms inference, 0.9ms postprocess per image at shape (1, 3, 800, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0060.jpg: 768x1280 39 pps, 39.2ms
# Speed: 5.4ms preprocess, 39.2ms inference, 2.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0061.jpg: 832x1280 17 pps, 44.3ms
# Speed: 6.7ms preprocess, 44.3ms inference, 0.9ms postprocess per image at shape (1, 3, 832, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0062.jpg: 736x1280 6 pps, 38.5ms
# Speed: 4.2ms preprocess, 38.5ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0063.jpg: 960x1280 20 pps, 52.1ms
# Speed: 5.4ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0064.jpg: 736x1280 36 pps, 40.1ms
# Speed: 5.0ms preprocess, 40.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0065.jpg: 800x1280 20 pps, 40.5ms
# Speed: 4.9ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0066.jpg: 864x1280 20 pps, 43.5ms
# Speed: 5.9ms preprocess, 43.5ms inference, 0.9ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0067.jpg: 672x1280 21 pps, 36.2ms
# Speed: 3.9ms preprocess, 36.2ms inference, 1.2ms postprocess per image at shape (1, 3, 672, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0068.jpg: 960x1280 20 pps, 51.6ms
# Speed: 5.2ms preprocess, 51.6ms inference, 0.9ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0069.jpg: 736x1280 47 pps, 37.2ms
# Speed: 4.3ms preprocess, 37.2ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0070.jpg: 576x1280 15 pps, 29.7ms
# Speed: 3.8ms preprocess, 29.7ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0071.jpg: 864x1280 5 pps, 45.6ms
# Speed: 5.1ms preprocess, 45.6ms inference, 1.2ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0072.jpg: 864x1280 7 pps, 46.2ms
# Speed: 4.5ms preprocess, 46.2ms inference, 1.1ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0073.jpg: 960x1280 12 pps, 51.1ms
# Speed: 5.8ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0074.jpg: 864x1280 42 pps, 43.8ms
# Speed: 5.4ms preprocess, 43.8ms inference, 1.2ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0075.jpg: 896x1280 27 pps, 48.3ms
# Speed: 4.9ms preprocess, 48.3ms inference, 3.2ms postprocess per image at shape (1, 3, 896, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0076.jpg: 832x1280 14 pps, 50.1ms
# Speed: 3.8ms preprocess, 50.1ms inference, 0.8ms postprocess per image at shape (1, 3, 832, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0077.jpg: 1280x960 15 pps, 50.5ms
# Speed: 5.7ms preprocess, 50.5ms inference, 0.9ms postprocess per image at shape (1, 3, 1280, 960)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0078.jpg: 864x1280 (no detections), 45.0ms
# Speed: 5.6ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0079.jpg: 800x1280 28 pps, 40.1ms
# Speed: 4.7ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 800, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0080.jpg: 864x1280 17 pps, 47.1ms
# Speed: 5.0ms preprocess, 47.1ms inference, 0.8ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0081.jpg: 864x1280 14 pps, 46.4ms
# Speed: 4.9ms preprocess, 46.4ms inference, 3.0ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0082.jpg: 736x1280 12 pps, 38.6ms
# Speed: 4.0ms preprocess, 38.6ms inference, 0.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0083.jpg: 864x1280 43 pps, 44.4ms
# Speed: 5.6ms preprocess, 44.4ms inference, 0.8ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0084.jpg: 864x1280 39 pps, 46.8ms
# Speed: 6.3ms preprocess, 46.8ms inference, 1.2ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0085.jpg: 864x1280 4 pps, 46.3ms
# Speed: 7.0ms preprocess, 46.3ms inference, 2.3ms postprocess per image at shape (1, 3, 864, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0086.jpg: 960x1280 29 pps, 52.0ms
# Speed: 5.7ms preprocess, 52.0ms inference, 0.8ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0087.jpg: 960x1280 37 pps, 52.1ms
# Speed: 5.3ms preprocess, 52.1ms inference, 1.3ms postprocess per image at shape (1, 3, 960, 1280)
#
# image 1/1 /home/stevenyang/Desktop/cmput469/YOLO/NWPU_60/img/0088.jpg: 864x1280 13 pps, 47.0ms
# Speed: 5.1ms preprocess, 47.0ms inference, 0.9ms postprocess per image at shape (1, 3, 864, 1280)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 45
#      42 count = 0
#      44 for x in range(1,685):
# ---> 45     gt, p = eval(x)
#      46     if gt is not None and p is not None:
#      47         err = abs(int(gt) - int(p))
#
# Cell In[24], line 25, in eval(index)
#      22     print(f"Annotation file {mat_path} not found.")
#      23     return None, None
# ---> 25 img = cv2.imread(img_path)
#      26 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      28 mat_data = scipy.io.loadmat(mat_path)
#
# KeyboardInterrupt:
